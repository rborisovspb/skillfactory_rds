# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
answer_ls=[]

# %%
answer_ls.append(4)

# %%
max_budget = data[data.budget==data.budget.max()]
max_budget['original_title']
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
answer_ls.append(2)

# %%
a = data.query('runtime==runtime.max()')
a.get('original_title')
# Out:
# 1158    Gods and Generals
# Name: original_title, dtype: object

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
a = data.query('runtime==runtime.min()')
a.get('original_title')
# Out:
# 769    Winnie the Pooh
# Name: original_title, dtype: object

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['income']=data['revenue'] - data['budget']
a = data[data.income==data.income.max()]
display(a)
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year      income
# 239        8458           7.1          2009  2544505847

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data['income']=data['revenue'] - data['budget']
a = data[data.income==data.income.min()]
display(a)
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     income
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
new_df=data[data.income > 0]
new_df.count()
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# income                  1478
# dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
new_data = data[data.release_year == 2008]
display(new_data[new_data.income == new_data.income.max()])
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year     income
# 600        8432           8.1          2008  816921825

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
answer_ls.append(5)

# %%
new_data = data[(data.release_year >=2012) & (data.release_year <=2014)]
display(new_data[new_data.income == new_data.income.min()])
# Out:
#         imdb_id  popularity     budget   revenue   original_title  \
# 1246  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1246  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1246  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1246  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1246  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_count  vote_average  release_year     income
# 1246        1607           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
answer_ls.append(1)

# %%
new_data=data.genres.apply(genres_list)

# %%
genres = {}
def genres_list(list_genres):
    new_list = list_genres.split('|')
    for i in new_list:
        if i in genres:
            genres[i] +=1
        else:
            genres[i] = 1
    return genres

# %%
display(new_data[0])
# Out:
# {'Action': 1169,
#  'Adventure': 835,
#  'Science Fiction': 499,
#  'Thriller': 1197,
#  'Fantasy': 446,
#  'Crime': 630,
#  'Western': 40,
#  'Drama': 1564,
#  'Family': 520,
#  'Animation': 278,
#  'Comedy': 1366,
#  'Mystery': 336,
#  'Romance': 616,
#  'War': 116,
#  'History': 124,
#  'Music': 128,
#  'Horror': 352,
#  'Documentary': 16,
#  'Foreign': 4}

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
display(data)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# ...

# %%
genres = {}
display(data.query('income > 0').genres.apply(genres_list)[0])
# Out:
# {'Action': 444,
#  'Adventure': 337,
#  'Science Fiction': 195,
#  'Thriller': 446,
#  'Fantasy': 188,
#  'Crime': 231,
#  'Western': 12,
#  'Drama': 560,
#  'Family': 226,
#  'Animation': 120,
#  'Comedy': 551,
#  'Mystery': 119,
#  'Romance': 242,
#  'War': 41,
#  'History': 46,
#  'Music': 47,
#  'Horror': 150,
#  'Documentary': 7}

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
directors_list={}
def directors_list_calc(director):
    new_list = director.split('|')
    for i in new_list:
        if i in directors_list:
            directors_list[i] +=1
        else:
            directors_list[i] =1
    return directors_list

# %%
director = 'Colin Trevorrow'
directors_list_calc(director)
# Out:
# {'Colin Trevorrow': 1}

# %%
display(data)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# 5     tt1663202    9.110700  135000000   532950503
# 6     tt1340138    8.654359  155000000   440603537
# 7     tt3659388    7.667400  108000000   595380321
# 8     tt2293640    7.404165   74000000  1156730962
# 9     tt2096673    6.326804  175000000   853708609
# 10    tt2379713    6.200282  245000000   880674609
# 11    tt1617661    6.189369  176000003   183987723
# 12    tt0470752    6.118847   15000000    36869414
# 13    tt2120120    5.984995   88000000   243637091
# 14    tt2395427    5.944927  280000000  1405035767
# 15    tt3460252    5.898400   44000000   155760117
# 16    tt2446042    5.749758   48000000   325771424
# ...

# %%
a = 'Pete Docter'
directors_list_calc(a)
# Out:
# {'Pete Docter': 1}

# %%
import operator
sorted_x = sorted(directors.items(), key=operator.itemgetter(1))
display(sorted_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-1c1b664c82b2> in <module>
#       1 import operator
# ----> 2 sorted_x = sorted(directors.items(), key=operator.itemgetter(1))
#       3 display(sorted_x)
#
# NameError: name 'directors' is not defined

# %%
Counter(sorted(directors.values(), key=lambda t: t[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d6b137b7d0ad> in <module>
# ----> 1 Counter(sorted(directors.values(), key=lambda t: t[0]))
#
# NameError: name 'directors' is not defined

# %%
answer_ls.append(1)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
answer_ls.append(1)

# %%
directors_list={}
def directors_list_calc(director):
    new_list = director.split('|')
    for i in new_list:
        if i in directors_list:
            directors_list[i] +=1
        else:
            directors_list[i] =1
    return directors_list

# %%
data['director'] = data.director.apply(lambda x : x.split('|'))

# %%
directors_with_income = data.query('income >0').director.apply(directors_list_calc)[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-30273193725b> in <module>
# ----> 1 directors_with_income = data.query('income >0').director.apply(directors_list_calc)[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-43-4f2e0ca05ce2> in directors_list_calc(director)
#       1 directors_list={}
#       2 def directors_list_calc(director):
# ----> 3     new_list = director.split('|')
#       4     for i in new_list:
#       5         if i in directors_list:
#
# ...

# %%
display(data)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# 5     tt1663202    9.110700  135000000   532950503
# 6     tt1340138    8.654359  155000000   440603537
# 7     tt3659388    7.667400  108000000   595380321
# 8     tt2293640    7.404165   74000000  1156730962
# 9     tt2096673    6.326804  175000000   853708609
# 10    tt2379713    6.200282  245000000   880674609
# 11    tt1617661    6.189369  176000003   183987723
# 12    tt0470752    6.118847   15000000    36869414
# 13    tt2120120    5.984995   88000000   243637091
# 14    tt2395427    5.944927  280000000  1405035767
# 15    tt3460252    5.898400   44000000   155760117
# 16    tt2446042    5.749758   48000000   325771424
# ...

# %%
import pandas as pd
print(pd._version-_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e341db0af5f8> in <module>
#       1 import pandas as pd
# ----> 2 print(pd._version_)
#
# AttributeError: module 'pandas' has no attribute '_version_'

# %%
df = pd.DataFrame({'A': [[1, 2, 3], 'foo', [], [3, 4]], 'B': 1})
df
# Out:
#            A  B
# 0  [1, 2, 3]  1
# 1        foo  1
# 2         []  1
# 3     [3, 4]  1

# %%
df.append(['baa', 2], axis =1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2e833237c185> in <module>
# ----> 1 df.append(['baa', 2], axis =1)
#
# TypeError: append() got an unexpected keyword argument 'axis'

# %%
df
# Out:
#            A  B
# 0  [1, 2, 3]  1
# 1        foo  1
# 2         []  1
# 3     [3, 4]  1

# %%
import operator
sorted_x = sorted(directors_with_income.items(), key=operator.itemgetter(1))
display(sorted_x)
# Out:
# [('Colin Trevorrow', 1),
#  ('Alex Garland', 1),
#  ('Sam Taylor-Johnson', 1),
#  ('Tom McCarthy', 1),
#  ('Lenny Abrahamson', 1),
#  ('Peter Sohn', 1),
#  ('John Crowley', 1),
#  ('Lee Toland Krieger', 1),
#  ('Ilya Naishuller', 1),
#  ('Jake Schreier', 1),
#  ('Ericson Core', 1),
#  ('Aleksander Bach', 1),
#  ('Ryan Coogler', 1),
#  ('Peter Landesman', 1),
#  ('John Francis Daley', 1),
#  ('Jonathan M. Goldstein', 1),
#  ('Joel Edgerton', 1),
#  ('Jocelyn Moorhouse', 1),
#  ('Ari Sandel', 1),
#  ('Ciaran Foy', 1),
#  ('Doug Ellin', 1),
#  ('Jeremy Garelick', 1),
#  ('Michael Dougherty', 1),
#  ('Dean Israelite', 1),
#  ('Gregory Jacobs', 1),
#  ('Gregory Plotkin', 1),
#  ('Billy Ray', 1),
#  ('Paul Tibbitt', 1),
#  ('Leigh Whannell', 1),
#  ('Nicholas Hytner', 1),
#  ('David M. Rosenthal', 1),
#  ('Etan Cohen', 1),
#  ('Sarah Gavron', 1),
#  ('Max Joseph', 1),
#  ('Chad Stahelski', 1),
#  ('David Leitch', 1),
#  ('Don Hall', 1),
#  ('Morten Tyldum', 1),
#  ('Dan Gilroy', 1),
# ...

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
new_df = data.explode('director')
grouped_df = new_df.groupby(['director']).sum()
display(grouped_df.sort_values('income'))
# Out:
#                        popularity      budget     revenue  runtime  \
# director
# Sngmoo Lee               0.250540   425000000    11087569      100
# James L. Brooks          1.682857   200000000   103710274      251
# Ron Underwood            0.912373   100000000     7103973       95
# Peter Hyams              0.818466   120000000    33043455      214
# David Bowers|Sam Fell    1.390297   149000000    64459316       85
# ...                           ...         ...         ...      ...
# Michael Bay             15.241191  1126000000  3886938960     1209
# J.J. Abrams             24.004784   740000000  3579169916      633
# Christopher Nolan       61.560756  1005000000  4167548502     1135
# David Yates             20.506537   775000000  4154295625      567
# Peter Jackson           45.679675  1288000000  6490593685     1355
#
#                        vote_count  vote_average  release_year      income
# director
# ...

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
def cast_list(x):
    list_cast = x.split('|')
    return list_cast

# %%
data['cast'] = data.cast.apply(cast_list)
new_df = data.explode('cast')

# %%
display(new_df.sort_values('income'))
# Out:
#         imdb_id  popularity     budget     revenue  original_title  \
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# ...         ...         ...        ...         ...             ...
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
#
#                      cast         director                       tagline  \
# 0             Chris Pratt  Colin Trevorrow             The park is open.
# ...

# %%
x = ['abc']
y = x[0]
print(y)
# Out:
# abc

# %%
grouped_data = new_df.groupby(['cast']).sum()
display(grouped_data.sort_values('income'))
# Out:
#                     popularity      budget     revenue  runtime  vote_count  \
# cast
# Jang Dong-gun         0.250540   425000000    11087569      100          74
# Ti Lung               0.250540   425000000    11087569      100          74
# Kate Bosworth         3.235636   515000000   145544332      541        1175
# Emilio EchevarrÃ­a    0.948560   145000000    25819961      137          60
# Elisabeth Harnois     0.921653   150000000    38992758       88         129
# ...                        ...         ...         ...      ...         ...
# Robert Downey Jr.    45.467071  1702300000  7018330161     1948       42918
# Ian McKellen         54.110613  1935000000  8022375777     1738       42756
# Rupert Grint         47.419739  1288000000  7696638290     1276       28599
# Daniel Radcliffe     49.813471  1348000000  7862990281     1475       30083
# Emma Watson          52.428017  1493000000  8159245597     1609       32702
#
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
a = new_df[new_df.release_year == 2012]
# Out:
#         imdb_id  popularity     budget     revenue          original_title  \
# 971   tt0848228    7.637767  220000000  1519557910            The Avengers
# 971   tt0848228    7.637767  220000000  1519557910            The Avengers
# 971   tt0848228    7.637767  220000000  1519557910            The Avengers
# 971   tt0848228    7.637767  220000000  1519557910            The Avengers
# 971   tt0848228    7.637767  220000000  1519557910            The Avengers
# ...         ...         ...        ...         ...                     ...
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
#
#                     cast                   director  \
# ...

# %%
answer_ls.append(3)

# %%
grouped_data = new_df[new_df.budget > new_df.budget.mean()].groupby(['cast']).count()
display(grouped_data.sort_values('income'))
# Out:
#                 imdb_id  popularity  budget  revenue  original_title  \
# cast
# 50 Cent               1           1       1        1               1
# Lena Olin             1           1       1        1               1
# Lennie James          1           1       1        1               1
# Leonard Nimoy         1           1       1        1               1
# Leslie Bibb           1           1       1        1               1
# ...                 ...         ...     ...      ...             ...
# Tom Cruise           15          15      15       15              15
# Eddie Murphy         15          15      15       15              15
# Angelina Jolie       16          16      16       16              16
# Adam Sandler         17          17      17       17              17
# Matt Damon           18          18      18       18              18
#
#                 director  tagline  overview  runtime  genres  \
# cast
# 50 Cent                1        1         1        1       1
# ...

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
answer_ls.append(1)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
answer_ls.append(2)

# %%
df_cage = new_df[new_df.cast == 'Nicolas Cage']
df_cage['genres'] = df_cage.genres.apply(cast_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-0e45defbfcde> in <module>
#       1 df_cage = new_df[new_df.cast == 'Nicolas Cage']
# ----> 2 df_cage['genres'] = df_cage.genres.apply(cast_list)
#
# NameError: name 'cast_list' is not defined

# %%
grouped_df = df_cage.groupby(['genres']).count()
display(grouped_df)
# Out:
# Empty DataFrame
# Columns: [imdb_id, popularity, budget, revenue, original_title, cast, director, tagline, overview, runtime, production_companies, release_date, vote_count, vote_average, release_year, income]
# Index: []

# %%
answer_ls.append(1)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
data['production_companies'] = data.production_companies.apply(cast_list)
display(data)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# ...

# %%
grouped_df = new_df[new_df.release_year == 2015]

# %%
new_df = data.explode('production_companies')
grouped_df = new_df[new_df.release_year == 2015].groupby('production_companies').count()
display(grouped_df.sort_values('income'))
# Out:
#                                         imdb_id  popularity  budget  revenue  \
# production_companies
# 3 Arts Entertainment                          1           1       1        1
# Mid Atlantic Films                            1           1       1        1
# Miramax Films                                 1           1       1        1
# Moonlighting Films                            1           1       1        1
# Nickelodeon Animation Studios                 1           1       1        1
# ...                                         ...         ...     ...      ...
# Columbia Pictures                             7           7       7        7
# Paramount Pictures                            7           7       7        7
# Twentieth Century Fox Film Corporation        8           8       8        8
# Universal Pictures                           10          10      10       10
# Warner Bros.                                 12          12      12       12
#
# ...

# %%
answer_ls.append(4)

# %%
new_df = data.explode('production_companies')
# Out:
#         imdb_id  popularity     budget     revenue  original_title  \
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# ...         ...         ...        ...         ...             ...
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
new_df['genres'] = new_df.genres.apply(cast_list)
new_df = new_df.explode('genres')

# %%
display(new_df)
# Out:
#         imdb_id  popularity     budget     revenue  original_title  \
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# ...         ...         ...        ...         ...             ...
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
new_df[new_df.genres == 'Comedy']
# Out:
#         imdb_id  popularity    budget    revenue           original_title  \
# 26    tt2637276    4.564549  68000000  215863606                    Ted 2
# 46    tt2361509    2.814802  35000000  194564672               The Intern
# 61    tt3152624    2.317670  35000000  140795793               Trainwreck
# 67    tt3530002    2.096273  25000000   52395996         The Night Before
# 76    tt1528854    1.904898  50000000  240360392             Daddy's Home
# ...         ...         ...       ...        ...                      ...
# 1838  tt0242423    0.912320  13000000   73180723  Dude, Whereâ€™s My Car?
# 1842  tt0183505    0.783530  51000000  149270999       Me, Myself & Irene
# 1847  tt0204946    0.736173  28000000   90449929              Bring It On
# 1863  tt0195945    0.492950  11000000   59827328              Next Friday
# 1872  tt0171433    0.623706  30000000   37036004        Keeping the Faith
#
#                                                    cast  \
# ...

# %%
group_df = new_df[new_df.genres == 'Comedy'].groupby('production_companies').sum()
display(group_df.sort_values('income'))
# Out:
#                                                     popularity     budget  \
# production_companies
# Walt Disney Pictures|Rickshaw Productions             0.506031    8000000
# Splendid Pictures|Maverick Films|Metro-Goldwyn-...    0.275919   26000000
# Miramax Films                                         0.478888    8000000
# Summit Entertainment|Robert Simonds Productions...    0.302377   35000000
# Gerber Pictures|Warner Bros.                          0.983805   40000000
# ...                                                        ...        ...
# Universal Pictures|Point Grey Pictures|Good Uni...    2.376309   18000000
# Legendary Pictures|Green Hat Films                    1.439458  103000000
# Paramount Pictures                                    4.847227   87000000
# Gold/Miller Productions|Wayans Bros. Entertainm...    3.265608   64000000
# Legendary Pictures|Green Hat Films|Warner Bros....    3.153060   35000000
#
# ...

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
def cast_list(x):
    list_cast = x.split('|')
    return list_cast

# %%
new_df = data
new_df['production_companies'] = data.production_companies.apply(cast_list)
new_df = new_df.explode('production_companies')
display(new_df)
# Out:
#         imdb_id  popularity     budget     revenue  original_title  \
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# ...         ...         ...        ...         ...             ...
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
new_df[new_df.release_year == 2012]
# Out:
#         imdb_id  popularity     budget     revenue          original_title  \
# 971   tt0848228    7.637767  220000000  1519557910            The Avengers
# 972   tt1496025    7.031452   70000000   132400000   Underworld: Awakening
# 972   tt1496025    7.031452   70000000   132400000   Underworld: Awakening
# 972   tt1496025    7.031452   70000000   132400000   Underworld: Awakening
# 972   tt1496025    7.031452   70000000   132400000   Underworld: Awakening
# ...         ...         ...        ...         ...                     ...
# 1080  tt1876451    0.308684   14000000    24637469                 Sparkle
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
# 1081  tt2215719    0.050524   12000000    32726956  Katy Perry: Part of Me
#
#                                                    cast  \
# ...

# %%
grouped_df = new_df[new_df.release_year == 2012].groupby('production_companies').sum()
display(grouped_df.sort_values('revenue'))
# Out:
#                         popularity     budget     revenue  runtime  \
# production_companies
# Wonderful Films PLC       0.903283   10000000     3428048      115
# Liddell Entertainment     0.903283   10000000     3428048      115
# LD Entertainment          0.903283   10000000     3428048      115
# Industry Entertainment    0.409718   20000000     4636169       97
# Paradox Entertainment     0.409718   20000000     4636169       97
# ...                            ...        ...         ...      ...
# Marvel Studios            7.637767  220000000  1519557910      143
# Relativity Media         21.538410  669000000  1701593938     1499
# Warner Bros.             12.593044  611500000  1869520056      579
# Universal Pictures       22.154145  920000000  2901011579     1295
# Columbia Pictures        26.856165  967000000  3468406608     1226
#
#                         vote_count  vote_average  release_year      income
# production_companies
# ...

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
answer_ls.append(3)

# %%
new_df = data
new_df = new_df.explode('production_companies')
new_df = new_df[new_df.production_companies == 'Paramount Pictures']
display(new_df.sort_values('income'))
# Out:
#         imdb_id  popularity     budget     revenue  \
# 926   tt0267626    0.722330  100000000    35168966
# 1124  tt0300556    1.047214   80000000    19480739
# 1723  tt0435705    1.068126   70000000    18211013
# 1624  tt0375173    0.898601   60000000    13395939
# 1632  tt0315297    0.767870   50000000    25195000
# ...         ...         ...        ...         ...
# 731   tt1229238    2.952740  145000000   694713380
# 1739  tt0418279    0.890557  150000000   709709780
# 604   tt0367882    3.161670  185000000   786636033
# 317   tt1055369    0.813323  150000000   836297228
# 829   tt1399103    0.760503  195000000  1123746996
#
#                                          original_title  \
# 926                                K-19: The Widowmaker
# 1124                                           Timeline
# 1723                                               Next
# 1624                                              Alfie
# 1632                                            Twisted
# ...

# %%
new_df = data
new_df['production_companies'] = data.production_companies.apply(cast_list)
new_df = new_df.explode('production_companies')
new_df = new_df[data.production_companies == 'Paramount Pictures']
display(new_df.sort_values('income'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-e7e734b6bd5a> in <module>
#       1 new_df = data
# ----> 2 new_df['production_companies'] = data.production_companies.apply(cast_list)
#       3 new_df = new_df.explode('production_companies')
#       4 new_df = new_df[data.production_companies == 'Paramount Pictures']
#       5 display(new_df.sort_values('income'))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-102-23a4b80ee6d6> in cast_list(x)
#       3 data.head(5)
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
grouped_data = data.groupby('release_year').sum()
display(grouped_data.sort_values('revenue'))
# Out:
#               popularity      budget      revenue  runtime  vote_count  \
# release_year
# 2000           83.906725  4562700000  10664099805     9956       39469
# 2001          118.804643  5067150000  13017764865    11284       54986
# 2002          127.017597  5134000000  14136361487    11528       54743
# 2003          129.851775  5117300000  14346123312    10623       57598
# 2006          143.461700  6083965000  14775042320    13952       61517
# 2005          141.030028  6327500000  15309425558    13387       59431
# 2004          142.901974  6029250000  15663430720    12014       66099
# 2007          146.148186  6596495000  18162406801    14305       72225
# 2008          158.907759  6588900000  18252781990    12979       84574
# 2009          175.264020  6838046652  20261791024    14187       97625
# 2010          179.199055  7965000000  21082292530    13692      106841
# 2011          205.056209  7946550531  22676791872    15355      113342
# ...

# %%
answer_ls.append(5)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
def cast_list(x):
    list_cast = x.split('|')
    return list_cast

# %%
new_df = data
new_df['production_companies'] = new_df.production_companies.apply(cast_list)
new_df = new_df.explode('production_companies')
display(new_df)
# Out:
#         imdb_id  popularity     budget     revenue  original_title  \
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# ...         ...         ...        ...         ...             ...
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
new_df[new_df.production_companies.str.match("Warner")]
# Out:
#         imdb_id  popularity     budget    revenue           original_title  \
# 11    tt1617661    6.189369  176000003  183987723        Jupiter Ascending
# 22    tt2126355    4.907832  110000000  470490832              San Andreas
# 40    tt1638355    3.053421   75000000  108145109  The Man from U.N.C.L.E.
# 46    tt2361509    2.814802   35000000  194564672               The Intern
# 59    tt1390411    2.345821  100000000   93820758  In the Heart of the Sea
# ...         ...         ...        ...        ...                      ...
# 1858  tt0177971    0.583320  120000000  325756637        The Perfect Storm
# 1874  tt0160009    0.339608   40000000   30199105           The Art of War
# 1879  tt0176783    0.310295   14000000    5108820                   Gossip
# 1883  tt0217756    0.196668   24000000   12372410          Ready to Rumble
# 1889  tt0163676    0.015997   15000000    5217498             The In Crowd
#
#                                                    cast  \
# ...

# %%
new_df = new_df[new_df.production_companies.str.match("Warner")]
grouped_df = new_df.groupby('release_year').sum()
display(grouped_df.sort_values('revenue'))
# Out:
#               popularity      budget     revenue  runtime  vote_count  \
# release_year
# 2000            7.641420   572900000  1025531386     1333        2163
# 2006           16.403998   959500000  1581832868     1692        7801
# 2015           30.133961   820800003  1691168351     1358       11574
# 2002           15.070224   680000000  1702709901     1281        5851
# 2012           12.593044   611500000  1869520056      579       11729
# 2001           21.572986   998000000  2280142579     1666       10622
# 2005           23.689897   875000000  2470278228     1392       13487
# 2013           22.296746   963500000  2599953400     1100       19352
# 2004           21.125522  1100000000  2731933725     1624       10964
# 2009           24.294407   915500000  2737954136     1305       16473
# 2003           18.345576   970000000  2814008221     1175        8660
# 2011           23.499629   974000000  2845393682     1248       15559
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
def cast_list(x):
    list_cast = x.split('|')
    return list_cast

# %%
data['month'] = pd.DatetimeIndex(data['release_date']).month
grouped_data = data.groupby('month').count()
display(grouped_data)
# Out:
#        imdb_id  popularity  budget  revenue  original_title  cast  director  \
# month
# 1          110         110     110      110             110   110       110
# 2          135         135     135      135             135   135       135
# 3          156         156     156      156             156   156       156
# 4          149         149     149      149             149   149       149
# 5          140         140     140      140             140   140       140
# 6          147         147     147      147             147   147       147
# 7          142         142     142      142             142   142       142
# 8          161         161     161      161             161   161       161
# 9          227         227     227      227             227   227       227
# 10         186         186     186      186             186   186       186
# 11         146         146     146      146             146   146       146
# ...

# %%
answer_ls.append(4)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
df = data.query('month in [6,7,8]')
df.count()
# Out:
# imdb_id                 450
# popularity              450
# budget                  450
# revenue                 450
# original_title          450
# cast                    450
# director                450
# tagline                 450
# overview                450
# runtime                 450
# genres                  450
# production_companies    450
# release_date            450
# vote_count              450
# vote_average            450
# release_year            450
# income                  450
# month                   450
# dtype: int64

# %%
answer_ls.append(2)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
df = data.query('month in [12,1,2]')
df.explode('director')
display(df)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 3     tt2488496   11.173104  200000000  2068178225
# 5     tt1663202    9.110700  135000000   532950503
# 11    tt1617661    6.189369  176000003   183987723
# 12    tt0470752    6.118847   15000000    36869414
# 15    tt3460252    5.898400   44000000   155760117
# ...         ...         ...        ...         ...
# 1864  tt0219653    0.481089   28000000    33000337
# 1868  tt0181536    0.449041   43000000    80049764
# 1873  tt0134983    0.385350   90000000    14828081
# 1881  tt0190374    0.284476   35000000    15185241
# 1888  tt0162983    0.031018   40000000    36037909
#
#                     original_title  \
# 3     Star Wars: The Force Awakens
# 5                     The Revenant
# 11               Jupiter Ascending
# 12                      Ex Machina
# 15               The Hateful Eight
# ...                            ...
# 1864                  Dracula 2000
# 1868             Finding Forrester
# ...

# %%
grouped_df = df.groupby('director').count()
display(grouped_df.sort_values('imdb_id'))
# Out:
#                                imdb_id  popularity  budget  revenue  \
# director
# Aaron Seltzer|Jason Friedberg        1           1       1        1
# McG                                  1           1       1        1
# Matthew Vaughn                       1           1       1        1
# Matthew O'Callaghan                  1           1       1        1
# Matt Reeves                          1           1       1        1
# ...                                ...         ...     ...      ...
# Adam Shankman                        4           4       4        4
# Shawn Levy                           4           4       4        4
# Steven Soderbergh                    6           6       6        6
# Clint Eastwood                       6           6       6        6
# Peter Jackson                        7           7       7        7
#
#                                original_title  cast  tagline  overview  \
# director
# ...

# %%
answer_ls.append(5)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
def cast_list(x):
    list_cast = x.split('|')
    return list_cast
data['month'] = pd.DatetimeIndex(data['release_date']).month

# %%
grouped_df = data.groupby(['release_year', 'month']).sum()
grouped_df.head(48)
# Out:
#                     popularity     budget     revenue  runtime  vote_count  \
# release_year month
# 2000         1        0.878300  101000000    74655409      189         112
#              2        4.717083  252300000   562437593      778        2840
#              3        8.002211  465000000   955709929      990        2739
#              4        6.066936  355000000   479362846     1117        1849
#              5       11.997521  419300000  1802022190      801        6247
#              6        6.765492  509000000  1026315528      858        3283
#              7        6.427635  468000000  1031809888      867        4541
#              8        3.931447  222000000   486018332      540        1663
#              9        4.660202  157000000   332306761      554        3322
#              10       8.709416  346600000   746538512      817        3916
#              11       8.125556  545500000  1033434818      787        3038
# ...

# %%
final_df = grouped_df.groupby(['release_year']).income.max()

# %%
final_df
# Out:
# release_year
# 2000    1411487999
# 2001    1703868124
# 2002    1848074177
# 2003    2000292657
# 2004    2412578839
# 2005    1575566228
# 2006    2098059770
# 2007    2764341802
# 2008    1943384763
# 2009    3423239738
# 2010    2449561498
# 2011    2331661017
# 2012    2965481705
# 2013    2411922008
# 2014    2279978281
# 2015    3757679861
# Name: income, dtype: int64

# %%
new_df = grouped_df['income'].unstack().idxmax(axis=1)

# %%
grouped_df.reset_index(inplace=True)

# %%
display(grouped_df)
# Out:
#      release_year  month  popularity     budget     revenue  runtime  \
# 0            2000      1    0.878300  101000000    74655409      189
# 1            2000      2    4.717083  252300000   562437593      778
# 2            2000      3    8.002211  465000000   955709929      990
# 3            2000      4    6.066936  355000000   479362846     1117
# 4            2000      5   11.997521  419300000  1802022190      801
# ..            ...    ...         ...        ...         ...      ...
# 187          2015      8   18.777991  337000001   828699147      858
# 188          2015      9   40.364813  733000000  2508686025     1913
# 189          2015     10   28.233503  546430000  1488591764     1497
# 190          2015     11   38.367038  764800000  1977508544     1690
# 191          2015     12   36.726252  592000000  3369325507      917
#
#      vote_count  vote_average      income
# 0           112          11.3   -26344591
# 1          2840          41.3   310137593
# ...

# %%
pivot = grouped_df.pivot_table(values = ['income'], index = ['release_year'], aggfunc = 'max')
display(pivot)
# Out:
#                   income
# release_year
# 2000          1411487999
# 2001          1703868124
# 2002          1848074177
# 2003          2000292657
# 2004          2412578839
# 2005          1575566228
# 2006          2098059770
# 2007          2764341802
# 2008          1943384763
# 2009          3423239738
# 2010          2449561498
# 2011          2331661017
# 2012          2965481705
# 2013          2411922008
# 2014          2279978281
# 2015          3757679861

# %%
joined = pivot.merge(grouped_df, on = 'income', how = 'left')

# %%
group = joined.groupby('month').count()
display(group)
# Out:
#        income  release_year  popularity  budget  revenue  runtime  vote_count  \
# month
# 5           4             4           4       4        4        4           4
# 6           7             7           7       7        7        7           7
# 7           1             1           1       1        1        1           1
# 12          4             4           4       4        4        4           4
#
#        vote_average
# month
# 5                 4
# 6                 7
# 7                 1
# 12                4

# %%
answer_ls.append(2)

# %%
pd.MultiIndex.from_frame(new_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-8b31cf548f44> in <module>
# ----> 1 new_df.MultiIndex.from_frame(new_df)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'MultiIndex'

# %%
new_df.rename('A')
# Out:
# release_year
# 2000    12
# 2001    12
# 2002    12
# 2003     5
# 2004     5
# 2005     5
# 2006     6
# 2007     6
# 2008     6
# 2009    12
# 2010     6
# 2011     7
# 2012     6
# 2013     6
# 2014     5
# 2015     6
# Name: A, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-76301df90883> in <module>
# ----> 1 new_df = new_df.rename(new_df.columns[0], axis = 1, columns='month')
#
# TypeError: rename() got an unexpected keyword argument 'columns'

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

# %%
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame({'a':randn(5), 'b':randn(5), 'c':randn(5)})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-23acf04ed2af> in <module>
# ----> 1 df = pd.DataFrame({'a':randn(5), 'b':randn(5), 'c':randn(5)})
#       2 df
#
# NameError: name 'randn' is not defined

# %%
grouped_data = data.groupby(['month', 'release_year']).sum()
display(grouped_data)
# Out:
#                     popularity      budget     revenue  runtime  vote_count  \
# month release_year
# 1     2000            0.878300   101000000    74655409      189         112
#       2001            2.443833    89000000   216876758      404         552
#       2002            4.027791   106000000   119657034      409         875
#       2003            2.033445    64000000   209423503      286         807
#       2004            4.584477   163000000   386449403      481        1710
# ...                        ...         ...         ...      ...         ...
# 12    2011           17.543036   692000000  2234580698     1589       10014
#       2012           13.642040   321000000  1426170337      847       13021
#       2013           27.256364   993000000  2708008475     1855       17940
#       2014           47.521994  1018800000  2937880286     1940       16493
#       2015           36.726252   592000000  3369325507      917       14627
#
# ...

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
def cast_list(x):
    list_cast = x.split('|')
    return list_cast
def name_len(x):
    leng = len(x.split(" "))
    return leng

# %%
data['name_len'] = data.original_title.apply(name_len)

# %%
data['production_companies'] = data.production_companies.apply(cast_list)
df = data.explode('production_companies')

# %%
display(df)
# Out:
#         imdb_id  popularity     budget     revenue  original_title  \
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# 0     tt0369610   32.985763  150000000  1513528810  Jurassic World
# ...         ...         ...        ...         ...             ...
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1888  tt0162983    0.031018   40000000    36037909      Hanging Up
# 1889  tt0163676    0.015997   15000000     5217498    The In Crowd
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
grouped_df = df.groupby('production_companies').mean()
display(grouped_df.sort_values('name_len'))
# Out:
#                                        popularity       budget      revenue  \
# production_companies
# Great Wight Productions/ Osford Films    0.587045   30000000.0  108609310.0
# Blue Sea Productions                     1.279087   25000000.0   20796847.0
# Blue Productions                         0.433748   25000000.0   30114487.0
# Maple Shade Films                        1.129322  100000000.0   82102379.0
# Many Rivers Productions                  2.754426   27000000.0  161849455.0
# ...                                           ...          ...          ...
# Dos Corazones                            0.628612   12000000.0    9622846.0
# The Saul Zaentz Company                  8.335347   86000000.0  898827882.0
# Polsky Films                             0.643829   25000000.0   10589102.0
# Jim Henson Company, The                  0.876514   28000000.0  100654149.0
# Four By Two Productions                  1.930735   18000000.0  261572744.0
#
# ...

# %%
answer_ls.append(5)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
answer_ls.append(1)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
def word_list(x):
    list_words = x.split(' ')
    return list_words

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
data['original_title'] = data.original_title.apply(word_list)
display(data)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                                    original_title  \
# 0                               [Jurassic, World]
# 1                         [Mad, Max:, Fury, Road]
# 2                                     [Insurgent]
# 3              [Star, Wars:, The, Force, Awakens]
# 4                                    [Furious, 7]
# ...

# %%
word_list = []
def cycle(title):
    for word in title:
        if word in word_list:
            continue
        else:
            word_list.append(word)

# %%
title = ['Jurassic', 'World']
cycle(title)

# %%
data['original_title'] = data.original_title.apply(cycle)
print(word_list)
# Out:
# ['Jurassic', 'World', 'Mad', 'Max:', 'Fury', 'Road', 'Insurgent', 'Star', 'Wars:', 'The', 'Force', 'Awakens', 'Furious', '7', 'Revenant', 'Terminator', 'Genisys', 'Martian', 'Minions', 'Inside', 'Out', 'Spectre', 'Jupiter', 'Ascending', 'Ex', 'Machina', 'Pixels', 'Avengers:', 'Age', 'of', 'Ultron', 'Hateful', 'Eight', 'Taken', '3', 'Ant-Man', 'Cinderella', 'Hunger', 'Games:', 'Mockingjay', '-', 'Part', '2', 'Tomorrowland', 'Southpaw', 'San', 'Andreas', 'Fifty', 'Shades', 'Grey', 'Big', 'Short', 'Mission:', 'Impossible', 'Rogue', 'Nation', 'Ted', 'Kingsman:', 'Secret', 'Service', 'Spotlight', 'Maze', 'Runner:', 'Scorch', 'Trials', 'Chappie', 'Pitch', 'Perfect', 'Bridge', 'Spies', 'Goosebumps', 'Room', 'Good', 'Dinosaur', 'Run', 'All', 'Night', 'Brooklyn', 'Straight', 'Outta', 'Compton', 'Last', 'Witch', 'Hunter', 'Man', 'from', 'U.N.C.L.E.', 'Adaline', 'Hardcore', 'Henry', 'Home', 'Paper', 'Towns', 'Carol', 'Intern', 'Everest', 'Point', 'Break', 'Burnt', 'Self/less', 'Mortdecai', 'Dan
# ...

# %%
len(word_list)
# Out:
# 2477

# %%
answer_ls.append(3)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
answer_ls.append(1)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
display(data.sort_values('vote_average'))
# Out:
#         imdb_id  popularity     budget     revenue        original_title  \
# 966   tt0295254    0.231392   40000000    18902015            FearDotCom
# 710   tt1213644    0.812489   25000000    14109284        Disaster Movie
# 1162  tt0317676    0.422393    7000000    13818181     House of the Dead
# 1761  tt0799949    0.571060   20000000    86865564            Epic Movie
# 1176  tt0339034    0.135162   12000000     4922166  From Justin to Kelly
# ...         ...         ...        ...         ...                   ...
# 9     tt2096673    6.326804  175000000   853708609            Inside Out
# 118   tt0816692   24.949134  165000000   621752480          Interstellar
# 34    tt3170832    3.557846    6000000    35401758                  Room
# 125   tt2084970    8.110711   14000000   233555708    The Imitation Game
# 600   tt0468569    8.466668  185000000  1001921825       The Dark Knight
#
#                                                    cast  \
# ...

# %%
data['cast'] = data.cast.apply(cast_list)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# ...

# %%
def cast_counter(cast_list):
    cast_count = 0
    if (x in cast_list) and (y in cast_list):
        cast_count +=1
    else:
        cast_count = cast_count
    return cast_count

# %%
cast_count = 0
x = 'Johnny Depp'
y = 'Helena Bonham Carter'
cast_list = ['Johnny Depp', 'Helena Bonham Carter']
cast_counter(cast_list)
# Out:
# 0

# %%
x = 'Daniel Radcliffe'
y = 'Rupert Grint'
data['flag'] = data.cast.apply(cast_counter)

# %%
new_df = data[data.flag == 1]
new_df.describe()
# Out:
#        popularity        budget       revenue     runtime  vote_count  \
# count    8.000000  8.000000e+00  8.000000e+00    8.000000     8.00000
# mean     5.788532  1.600000e+08  9.616482e+08  147.250000  3562.25000
# std      1.021262  5.775564e+07  1.588972e+08   10.443727   321.43373
# min      4.840588  1.000000e+08  7.898046e+08  130.000000  3220.00000
# 25%      5.026895  1.250000e+08  8.911129e+08  140.250000  3400.00000
# 50%      5.769548  1.400000e+08  9.360860e+08  149.000000  3462.50000
# 75%      5.958091  1.750000e+08  9.598483e+08  154.000000  3600.00000
# max      8.021423  2.500000e+08  1.327818e+09  161.000000  4265.00000
#
#        vote_average  release_year        income  flag
# count      8.000000      8.000000  8.000000e+00   8.0
# mean       7.337500   2006.125000  8.016482e+08   1.0
# std        0.168502      3.720119  1.735243e+08   0.0
# min        7.200000   2001.000000  6.598046e+08   1.0
# 25%        7.200000   2003.500000  6.992192e+08   1.0
# ...

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
answer_ls.append(1)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data = pd.read_csv('data.csv')
data['income']=data['revenue'] - data['budget']
display(data.sort_values('vote_average'))
# Out:
#         imdb_id  popularity     budget     revenue        original_title  \
# 966   tt0295254    0.231392   40000000    18902015            FearDotCom
# 710   tt1213644    0.812489   25000000    14109284        Disaster Movie
# 1162  tt0317676    0.422393    7000000    13818181     House of the Dead
# 1761  tt0799949    0.571060   20000000    86865564            Epic Movie
# 1176  tt0339034    0.135162   12000000     4922166  From Justin to Kelly
# ...         ...         ...        ...         ...                   ...
# 9     tt2096673    6.326804  175000000   853708609            Inside Out
# 118   tt0816692   24.949134  165000000   621752480          Interstellar
# 34    tt3170832    3.557846    6000000    35401758                  Room
# 125   tt2084970    8.110711   14000000   233555708    The Imitation Game
# 600   tt0468569    8.466668  185000000  1001921825       The Dark Knight
#
#                                                    cast  \
# ...

# %%
def cast_list(x):
    list_cast = x.split('|')
    return list_cast

# %%
data['director'] = data.director.apply(cast_list)

# %%
new_df = data.explode('director')

# %%
def income_flag(x):
    flag = 0
    if x >0:
        flag = 1
    else:
        flag = 0
    return flag

# %%
new_df['flag'] = new_df.income.apply(income_flag)
display(new_df)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# ...

# %%
x = 'Clint Eastwood'
total = 0
good = 0
total = len(new_df[new_df.director == x])
good = len(new_df[(new_df.director == x) & (new_df.flag ==1)])
result = good / total
print(result)
# Out:
# 0.8333333333333334

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 32

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       1
# 11  12       1
# 12  13       1
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       1
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       3
